# %% [markdown]
# <a href="https://colab.research.google.com/github/sbsonusunil/twitter_project/blob/main/04_how_does_a_neural_net_really_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fitting a function with *gradient descent*

# %%
from ipywidgets import interact
from fastai.basics import *

plt.rc('figure', dpi=90)

def plot_function(f, title=None, min=-2.1, max=2.1, color='r', ylim=None):
    x = torch.linspace(min,max, 100)[:,None]
    if ylim: plt.ylim(ylim)
    plt.plot(x, f(x), color)
    if title is not None: plt.title(title)

# %%
def f(x): return 3*x**2 + 2*x + 1

plot_function(f, "$3x^2 + 2x + 1$")

# %%
import torch
xt = tensor(3.).requires_grad_()
yt=f(xt)
yt
# Out:
# tensor(34., grad_fn=<AddBackward0>)

# %%
def quad(a, b, c, x): return a*x**2 + b*x + c

# %%
def mk_quad(a,b,c): return partial(quad, a,b,c)

# %%
f2 = mk_quad(3,2,1)
plot_function(f2)

# %%
def noise(x, scale): return np.random.normal(scale=scale, size=x.shape)
def add_noise(x, mult, add): return x * (1+noise(x,mult)) + noise(x,add)

# %%
import numpy as np
np.random.seed(42)

x = torch.linspace(-2, 2, steps=20)[:,None]
y = add_noise(f(x), 0.15, 1.5)
# Out:
# /tmp/ipykernel_1209/1958766108.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   def add_noise(x, mult, add): return x * (1+noise(x,mult)) + noise(x,add)

# %%
x[:5],y[:5]
# Out:
# (tensor([[-2.0000],
#          [-1.7895],
#          [-1.5789],
#          [-1.3684],
#          [-1.1579]]),
#  tensor([[11.8690],
#          [ 6.5433],
#          [ 5.9396],
#          [ 2.6304],
#          [ 1.7947]], dtype=torch.float64))

# %%
plt.scatter(x,y);

# %%
@interact(a=1.1, b=1.1, c=1.1)
def plot_quad(a, b, c):
    plt.scatter(x,y)
    plot_function(mk_quad(a,b,c), ylim=(-3,13))
# Out:
# interactive(children=(FloatSlider(value=1.1, description='a', max=3.3000000000000003, min=-1.1), FloatSlider(v…

# %%
def mae(preds, acts): return (torch.abs(preds-acts)).mean()

# %%
@interact(a=1.1, b=1.1, c=1.1)
def plot_quad(a, b, c):
    f = mk_quad(a,b,c)
    plt.scatter(x,y)
    loss = mae(f(x), y)
    plot_function(f, ylim=(-3,12), title=f"MAE: {loss:.2f}")
# Out:
# interactive(children=(FloatSlider(value=1.1, description='a', max=3.3000000000000003, min=-1.1), FloatSlider(v…

# %% [markdown]
# ## Automating gradient descent

# %%
def quad_mae(params):
    f = mk_quad(*params)
    return mae(f(x), y)

# %%
quad_mae([1.1, 1.1, 1.1])
# Out:
# tensor(2.4219, dtype=torch.float64)

# %%
abc = torch.tensor([1.1,1.1,1.1])

# %%
abc.requires_grad_()
# Out:
# tensor([1.1000, 1.1000, 1.1000], requires_grad=True)

# %%
loss = quad_mae(abc)
loss
# Out:
# tensor(2.4219, dtype=torch.float64, grad_fn=<MeanBackward0>)

# %%
loss.backward()

# %%
abc.grad
# Out:
# tensor([-1.3529, -0.0316, -0.5000])

# %%
with torch.no_grad():
    abc -= abc.grad*0.01
    loss = quad_mae(abc)

print(f'loss={loss:.2f}')
# Out:
# loss=2.40

# %%
for i in range(10):
    loss = quad_mae(abc)
    loss.backward()
    with torch.no_grad(): abc -= abc.grad*0.01
    print(f'step={i}; loss={loss:.2f}')
# Out:
# step=0; loss=2.40
# step=1; loss=2.36
# step=2; loss=2.30
# step=3; loss=2.21
# step=4; loss=2.11
# step=5; loss=1.98
# step=6; loss=1.85
# step=7; loss=1.72
# step=8; loss=1.58
# step=9; loss=1.46

# %% [markdown]
# ## How a neural network approximates any given function

# %%
def rectified_linear(m,b,x):
    y = m*x+b
    return torch.clip(y, 0.)

# %%
plot_function(partial(rectified_linear, 1,1))

# %%
import torch.nn.functional as F
def rectified_linear2(m,b,x): return F.relu(m*x+b)
plot_function(partial(rectified_linear2, 1,1))

# %%
@interact(m=1.5, b=1.5)
def plot_relu(m, b):
    plot_function(partial(rectified_linear, m,b), ylim=(-1,4))
# Out:
# interactive(children=(FloatSlider(value=1.5, description='m', max=4.5, min=-1.5), FloatSlider(value=1.5, descr…

# %%
def double_relu(m1,b1,m2,b2,x):
    return rectified_linear(m1,b1,x) + rectified_linear(m2,b2,x)

@interact(m1=-1.5, b1=-1.5, m2=1.5, b2=1.5)
def plot_double_relu(m1, b1, m2, b2):
    plot_function(partial(double_relu, m1,b1,m2,b2), ylim=(-1,6))
# Out:
# interactive(children=(FloatSlider(value=-1.5, description='m1', max=1.5, min=-4.5), FloatSlider(value=-1.5, de…

# %% [markdown]
# ## How to recognise an owl
